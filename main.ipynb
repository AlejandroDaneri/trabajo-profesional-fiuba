# %%
import sys
sys.path.append("./algolibmodule")

# %%
# %pip install session_info
from algolib import AlgoLib
import session_info
session_info.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 2.5 MB/s eta 0:00:00
# ...
#   Created wheel for session_info: filename=session_info-1.0.0-py3-none-any.whl size=8048 sha256=e223d764702ea978404d2409158c7dee82223949a8f80cddc7320f01ad4f6bfc
#   Stored in directory: /home/ale/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session_info
# ...
# Note: you may need to restart the kernel to use updated packages.
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# algolib             NA
# pandas              1.5.3
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 9.0.1
# appdirs             1.4.4
# apport_python_hook  NA
# asttokens           NA
# backcall            0.2.0
# ...

# %%
rounds=14
ticker = 'BTC-USD'
start_date = '2000-01-01'
fast_period , slow_period = 20, 60
sigma = 40

algo_lib = AlgoLib(ticker, start_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ## Indicadores Estadisticos

# %% [markdown]
# ### RSI

# %%
algo_lib.RSI(rounds)
algo_lib.get_data().head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100
#
#                  diff        win       loss   EMA_win   EMA_loss        RS  \
# Date
# 2014-09-17        NaN   0.000000   0.000000  0.000000   0.000000       NaN
# 2014-09-18 -32.894012   0.000000  32.894012  0.000000  17.056155  0.000000
# 2014-09-19 -29.644012   0.000000  29.644012  0.000000  21.566612  0.000000
# 2014-09-20  14.108002  14.108002   0.000000  3.928194  15.561662  0.252428
# 2014-09-21 -10.082977   0.000000  10.082977  3.022024  14.297818  0.211363
#
#                   RSI
# Date
# 2014-09-17        NaN
# 2014-09-18   0.000000
# ...

# %%
algo_lib.plot_RSI()

# %% [markdown]
# ### MACD

# %%
algo_lib.MACD(23, 12, 9)
algo_lib.get_data().head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100
#
#                  diff        win       loss   EMA_win   EMA_loss        RS  \
# Date
# 2014-09-17        NaN   0.000000   0.000000  0.000000   0.000000       NaN
# 2014-09-18 -32.894012   0.000000  32.894012  0.000000  17.056155  0.000000
# 2014-09-19 -29.644012   0.000000  29.644012  0.000000  21.566612  0.000000
# 2014-09-20  14.108002  14.108002   0.000000  3.928194  15.561662  0.252428
# 2014-09-21 -10.082977   0.000000  10.082977  3.022024  14.297818  0.211363
#
#                   RSI    ema_fast    ema_slow      macd    signal  histogram
# Date
# ...

# %%
algo_lib.plot_MACD()

# %% [markdown]
# Backtest RSI

# %%
algo_lib2 = AlgoLib(ticker, '2021-01-01')
algo_lib2.backtesting()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-12  35516.359375  36568.527344  32697.976562  33922.960938
# 2021-01-14  37325.109375  39966.406250  36868.562500  39187.328125
# 2021-01-17  36163.648438  36722.351562  34069.320312  35791.277344
# 2021-02-08  38886.828125  46203.929688  38076.324219  46196.464844
# 2021-02-25  49709.082031  51948.968750  47093.851562  47093.851562
# 2021-03-10  54824.011719  57258.253906  53290.890625  56008.550781
# 2021-03-22  57517.890625  58471.480469  54288.156250  54529.144531
# 2021-04-13  59890.019531  63742.285156  59869.957031  63503.457031
# 2021-04-18  60701.886719  61057.457031  52829.535156  56216.183594
# 2021-07-27  37276.035156  39406.941406  36441.726562  39406.941406
# 2021-08-30  48834.851562  48925.605469  46950.273438  47054.984375
# ...
