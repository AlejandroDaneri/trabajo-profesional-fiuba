# %%
from lib.indicators.rsi import RSI
from lib.indicators.mfi import MFI
from lib.indicators.macd import MACD
from lib.indicators.nvi import NVI
from lib.indicators.koncorde import KONCORDE
from lib.indicators.ema import EMA

indicators = [
    MACD(23,12,9),
    RSI(30, 70, 14),
    EMA(14),
    MFI(20, 80, 14),
    NVI(255),
    KONCORDE(15)
]

# %%
from lib.strategies.LSTMstrategy import LSTM
# Out:
# 2024-04-14 22:06:10.354036: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-14 22:06:10.356494: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-14 22:06:10.388392: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 22:06:10.388418: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 22:06:10.389154: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 22:06:10.394178: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-14 22:06:10.394671: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-14 22:06:11.129223: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Necesitamos tener cargado el model_info.csv y la carpeta model con el modelo de Keras en el Root de algo_trader

# %%
strategy = LSTM(indicators)
# Out:
# 2.15.0

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime
# Binance Client
try:
  from binance.client import Client as BinanceProvider
except ModuleNotFoundError:
  # !pip install python-binance
  from binance.client import Client as BinanceProvider

# Define the ticker symbol for Bitcoin (BTC-USD)
ticker = "BTCUSDT"

# Download historical data using yfinance
api_key = "OF6SkzXI0EAcvmMWlkeUKl6YyxYIFU4pN0Bj19gaVYZcgaTt7OImXxEyvoPcDhmk"
secret_key = "tXay1BDYuSyigxvl27UQIBJbIHADaep8FT7HPO9Mb3vfmcyDkz4keEaHkpm7dcFe"
provider= BinanceProvider(api_key, secret_key, tld='us')

klines = provider.get_historical_klines(ticker,BinanceProvider.KLINE_INTERVAL_1MINUTE, "23 Mar, 2024")
bitcoin_data = pd.DataFrame(klines, columns = ["Open time", "Open", "High", "Low", "Close", "Volume", "Close time", "Quote asset volume"," Number of trades"," Taker buy base asset volume", "Taker buy quote asset volume", "Ignore"])
bitcoin_data['Date'] = bitcoin_data['Open time'].apply(lambda x : datetime.fromtimestamp(x / 1000).strftime('%Y-%m-%d %H:%M:%S'))

bitcoin_data['Close'] =  bitcoin_data['Close'].apply(lambda x : float(x))
bitcoin_data["High"] = bitcoin_data["High"].apply(lambda x: float(x))
bitcoin_data["Low"] = bitcoin_data["Low"].apply(lambda x: float(x))
bitcoin_data["Volume"] = bitcoin_data["Volume"].apply(lambda x: float(x))
bitcoin_data["Open"] = bitcoin_data["Open"].apply(lambda x: float(x))

bitcoin_data = bitcoin_data.drop('Open time', axis=1)
bitcoin_data = bitcoin_data.set_index("Date")

# Display the first few rows of the data
print(bitcoin_data.head())
bitcoin_data.info()
# Out:
#                          Open      High       Low     Close   Volume  \
# Date
# 2024-03-22 21:00:00  63811.05  63834.63  63716.12  63816.47  0.19647
# 2024-03-22 21:01:00  63670.83  63816.42  63670.83  63781.04  0.01215
# 2024-03-22 21:02:00  63781.05  63781.07  63752.88  63752.89  0.08443
# 2024-03-22 21:03:00  63655.96  63781.04  63655.96  63697.74  0.15912
# 2024-03-22 21:04:00  63782.00  63810.98  63782.00  63810.98  0.06617
#
#                         Close time Quote asset volume   Number of trades  \
# Date
# 2024-03-22 21:00:00  1711152059999     12536.99390710                 21
# 2024-03-22 21:01:00  1711152119999       773.67209910                  7
# 2024-03-22 21:02:00  1711152179999      5384.95593900                 11
# 2024-03-22 21:03:00  1711152239999     10135.66263490                  8
# 2024-03-22 21:04:00  1711152299999      4220.50941530                  5
#
#                      Taker buy base asset volume Taker buy quote asset volume  \
# Date
# 2024-03-22 21:00:00                   0.01190000                 759.53792010
# 2024-03-22 21:01:00                   0.00060000                  38.27393850
# 2024-03-22 21:02:00                   0.08443000                5384.95593900
# 2024-03-22 21:03:00                   0.00122000                  77.79084890
# 2024-03-22 21:04:00                   0.06617000                4220.50941530
#
#                     Ignore
# Date
# 2024-03-22 21:00:00      0
# 2024-03-22 21:01:00      0
# 2024-03-22 21:02:00      0
# 2024-03-22 21:03:00      0
# 2024-03-22 21:04:00      0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33187 entries, 2024-03-22 21:00:00 to 2024-04-14 22:06:00
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Open                          33187 non-null  float64
#  1   High                          33187 non-null  float64
#  2   Low                           33187 non-null  float64
#  3   Close                         33187 non-null  float64
#  4   Volume                        33187 non-null  float64
#  5   Close time                    33187 non-null  int64
#  6   Quote asset volume            33187 non-null  object
#  7    Number of trades             33187 non-null  int64
#  8    Taker buy base asset volume  33187 non-null  object
#  9   Taker buy quote asset volume  33187 non-null  object
#  10  Ignore                        33187 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 3.0+ MB

# %%
import numpy as np

bitcoin_data_subset =  bitcoin_data[["Open", "High", "Low", "Close","Volume"]].copy()
bitcoin_data_subset["r"] = np.log(bitcoin_data_subset["Close"] / bitcoin_data_subset["Close"].shift(1))
bitcoin_data_subset = bitcoin_data_subset.rename_axis('Date')
bitcoin_data_subset.index = pd.to_datetime(bitcoin_data_subset.index)

bitcoin_data_subset.info()

df_except_last = bitcoin_data_subset.iloc[:-1]

# DataFrame con solo la última fila
df_last = bitcoin_data_subset.tail(1)
print(type(df_last))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 33187 entries, 2024-03-22 21:00:00 to 2024-04-14 22:06:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    33187 non-null  float64
#  1   High    33187 non-null  float64
#  2   Low     33187 non-null  float64
#  3   Close   33187 non-null  float64
#  4   Volume  33187 non-null  float64
#  5   r       33186 non-null  float64
# dtypes: float64(6)
# memory usage: 1.8 MB
# <class 'pandas.core.frame.DataFrame'>

# %%
strategy.prepare_data(df_except_last)

# %%
strategy.predict(df_last)
# Out:
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_{nperiod}'] = macd
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_signal_{nperiod}'] = macd_signal
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_upper_{nperiod}'] = bb_upper
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_middle_{nperiod}'] = bb_middle
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_lower_{nperiod}'] = bb_lower
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EWO_{nperiod}'] = ta.SMA(df['Close'], timeperiod=(period+5)) - ta.SMA(df['Close'], timeperiod=(period+35))
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ATR_{nperiod}'] = ta.ATR(df['High'], df['Low'], df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EMA_{nperiod}'] = ta.EMA(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'RSI_{nperiod}'] = ta.RSI(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'VWAP_{nperiod}'] = ta.SUM(df['Volume'] * (df['High'] + df['Low'] + df['Close']) / 3, timeperiod=period) / ta.SUM(df['Volume'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ROC_{nperiod}'] = ta.ROC(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_upper_{nperiod}'] = ta.EMA(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_middle_{nperiod}'] = ta.EMA(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_upper_{nperiod}'] = ta.MAX(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_lower_{nperiod}'] = ta.MIN(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_{nperiod}'] = macd
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_signal_{nperiod}'] = macd_signal
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_upper_{nperiod}'] = bb_upper
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_middle_{nperiod}'] = bb_middle
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_lower_{nperiod}'] = bb_lower
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EWO_{nperiod}'] = ta.SMA(df['Close'], timeperiod=(period+5)) - ta.SMA(df['Close'], timeperiod=(period+35))
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ATR_{nperiod}'] = ta.ATR(df['High'], df['Low'], df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EMA_{nperiod}'] = ta.EMA(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'RSI_{nperiod}'] = ta.RSI(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'VWAP_{nperiod}'] = ta.SUM(df['Volume'] * (df['High'] + df['Low'] + df['Close']) / 3, timeperiod=period) / ta.SUM(df['Volume'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ROC_{nperiod}'] = ta.ROC(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_upper_{nperiod}'] = ta.EMA(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_middle_{nperiod}'] = ta.EMA(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_upper_{nperiod}'] = ta.MAX(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_lower_{nperiod}'] = ta.MIN(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_{nperiod}'] = macd
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_signal_{nperiod}'] = macd_signal
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_upper_{nperiod}'] = bb_upper
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_middle_{nperiod}'] = bb_middle
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_lower_{nperiod}'] = bb_lower
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EWO_{nperiod}'] = ta.SMA(df['Close'], timeperiod=(period+5)) - ta.SMA(df['Close'], timeperiod=(period+35))
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ATR_{nperiod}'] = ta.ATR(df['High'], df['Low'], df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EMA_{nperiod}'] = ta.EMA(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'RSI_{nperiod}'] = ta.RSI(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'VWAP_{nperiod}'] = ta.SUM(df['Volume'] * (df['High'] + df['Low'] + df['Close']) / 3, timeperiod=period) / ta.SUM(df['Volume'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ROC_{nperiod}'] = ta.ROC(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_upper_{nperiod}'] = ta.EMA(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_middle_{nperiod}'] = ta.EMA(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_upper_{nperiod}'] = ta.MAX(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_lower_{nperiod}'] = ta.MIN(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_{nperiod}'] = macd
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_signal_{nperiod}'] = macd_signal
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_upper_{nperiod}'] = bb_upper
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_middle_{nperiod}'] = bb_middle
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_lower_{nperiod}'] = bb_lower
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EWO_{nperiod}'] = ta.SMA(df['Close'], timeperiod=(period+5)) - ta.SMA(df['Close'], timeperiod=(period+35))
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ATR_{nperiod}'] = ta.ATR(df['High'], df['Low'], df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EMA_{nperiod}'] = ta.EMA(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'RSI_{nperiod}'] = ta.RSI(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'VWAP_{nperiod}'] = ta.SUM(df['Volume'] * (df['High'] + df['Low'] + df['Close']) / 3, timeperiod=period) / ta.SUM(df['Volume'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ROC_{nperiod}'] = ta.ROC(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_upper_{nperiod}'] = ta.EMA(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_middle_{nperiod}'] = ta.EMA(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_upper_{nperiod}'] = ta.MAX(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_lower_{nperiod}'] = ta.MIN(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_{nperiod}'] = macd
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_signal_{nperiod}'] = macd_signal
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_upper_{nperiod}'] = bb_upper
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_middle_{nperiod}'] = bb_middle
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_lower_{nperiod}'] = bb_lower
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EWO_{nperiod}'] = ta.SMA(df['Close'], timeperiod=(period+5)) - ta.SMA(df['Close'], timeperiod=(period+35))
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ATR_{nperiod}'] = ta.ATR(df['High'], df['Low'], df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EMA_{nperiod}'] = ta.EMA(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'RSI_{nperiod}'] = ta.RSI(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'VWAP_{nperiod}'] = ta.SUM(df['Volume'] * (df['High'] + df['Low'] + df['Close']) / 3, timeperiod=period) / ta.SUM(df['Volume'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ROC_{nperiod}'] = ta.ROC(df['Close'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_upper_{nperiod}'] = ta.EMA(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'KC_middle_{nperiod}'] = ta.EMA(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_upper_{nperiod}'] = ta.MAX(df['High'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Donchian_lower_{nperiod}'] = ta.MIN(df['Low'], timeperiod=period)
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_{nperiod}'] = macd
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'MACD_signal_{nperiod}'] = macd_signal
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_upper_{nperiod}'] = bb_upper
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_middle_{nperiod}'] = bb_middle
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BB_lower_{nperiod}'] = bb_lower
# /home/ale/Documentos/trabajo_profesional_algo_trading/algo_trader/lib/strategies/LSTMstrategy.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'EWO_{nperiod}'] = ta.SMA(df['Close'], timeperiod=(period+5)) - ta.SMA(df['Close'], timeperiod=(period+35))
# <class 'numpy.ndarray'>
# 1/1 [==============================] - 1s 602ms/step
# [[0.5166102  0.48338982]]
# signal Action.SELL
# <Action.SELL: 'sell'>
